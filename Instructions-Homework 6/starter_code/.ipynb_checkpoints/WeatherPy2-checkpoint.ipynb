# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import time
import json
import seaborn as sns
from citipy import citipy
# Import API key
import api_keys


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 648

# %%
cities_df = pd.DataFrame({"city": cities })

cities_df = cities_df.drop_duplicates('city')

cities_df["country"] = ""
cities_df["cloudiness"] = ""
cities_df["date"] = ""
cities_df["humidity"] = ""
cities_df["lat"] = ""
cities_df["lon"] = ""
cities_df["temp_max"] = "" 
cities_df["wind_speed"] = ""

cities_df.head()
cities_df.dtypes
# Out:
# city          object
# country       object
# cloudiness    object
# date          object
# humidity      object
# lat           object
# lon           object
# temp_max      object
# wind_speed    object
# dtype: object

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key = "b12c496902bc510d29a8f3b9027c456a"

row_count = 0

print("**********************")
print("BEGINNING DATA RETRIEVAL")
print("**********************")
# Out:
# **********************
# BEGINNING DATA RETRIEVAL
# **********************

# %%
for index, row in cities_df.iterrows():
    target_url = "http://api.openweathermap.org/data/2.5/weather?q=%s&units=IMPERIAL&appid=%s" %(row['city'], api_key)
    response = requests.get(target_url).json()
    print("------------------------")
    print("Retrieving city #%s: %s" % (row_count + 1, cities_df.loc[index]['city']))
    print(target_url)
    row_count += 1
    
    try:
        cities_df.set_value(index, "lat", response["coord"]["lat"])
        cities_df.set_value(index, "lon", response["coord"]["lon"])
        cities_df.set_value(index, "date", response["dt"])
        cities_df.set_value(index, "humidity", response["main"]["humidity"])
        cities_df.set_value(index, "wind_speed", response["wind"]["speed"])
        cities_df.set_value(index, "temp_max", response["main"]["temp_max"])
        cities_df.set_value(index, "cloudiness", response["clouds"]["all"])
        cities_df.set_value(index, "country", response["sys"]['country'])
        
    except:
        
        print("Missing details... skip.")
                
        if row_count % 50 == 0:
          print("********************")
          print("PAUSE FOR 30 SECONDS")
          print("********************")
          time.sleep (30)
                 
print("**********************")
print("DATA RETRIEVAL COMPLETE")
print("**********************")
# Out:
# ------------------------
# Retrieving city #1: comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #2: ternate
# http://api.openweathermap.org/data/2.5/weather?q=ternate&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Retrieving city #3: meulaboh
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #4: ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #5: angoche
# http://api.openweathermap.org/data/2.5/weather?q=angoche&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #6: bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #7: taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #8: hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #9: rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #10: punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #11: upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #12: barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #13: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #14: avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #15: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #16: nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #17: bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #18: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #19: mogadishu
# http://api.openweathermap.org/data/2.5/weather?q=mogadishu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #20: bergen
# http://api.openweathermap.org/data/2.5/weather?q=bergen&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #21: sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #22: cockburn town
# http://api.openweathermap.org/data/2.5/weather?q=cockburn town&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #23: thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #24: port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #25: barranca
# http://api.openweathermap.org/data/2.5/weather?q=barranca&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #26: hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #27: gusinoye ozero
# http://api.openweathermap.org/data/2.5/weather?q=gusinoye ozero&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #28: mys shmidta
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #29: tierra blanca
# http://api.openweathermap.org/data/2.5/weather?q=tierra blanca&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #30: quesnel
# http://api.openweathermap.org/data/2.5/weather?q=quesnel&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #31: katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #32: vostok
# http://api.openweathermap.org/data/2.5/weather?q=vostok&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #33: nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #34: georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #35: sovetskiy
# http://api.openweathermap.org/data/2.5/weather?q=sovetskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #36: saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #37: puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=puerto escondido&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #38: coihaique
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #39: taoudenni
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #40: turukhansk
# http://api.openweathermap.org/data/2.5/weather?q=turukhansk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #41: vila velha
# http://api.openweathermap.org/data/2.5/weather?q=vila velha&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #42: esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #43: sept-iles
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #44: alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #45: jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #46: nassjo
# http://api.openweathermap.org/data/2.5/weather?q=nassjo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #47: busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #48: aksu
# http://api.openweathermap.org/data/2.5/weather?q=aksu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #49: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #50: mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #51: sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #52: rundu
# http://api.openweathermap.org/data/2.5/weather?q=rundu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #53: sortavala
# http://api.openweathermap.org/data/2.5/weather?q=sortavala&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #54: new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #55: klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #56: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #57: machico
# http://api.openweathermap.org/data/2.5/weather?q=machico&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #58: albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #59: ventspils
# http://api.openweathermap.org/data/2.5/weather?q=ventspils&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #60: yebaishou
# http://api.openweathermap.org/data/2.5/weather?q=yebaishou&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #61: shingu
# http://api.openweathermap.org/data/2.5/weather?q=shingu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #62: thoen
# http://api.openweathermap.org/data/2.5/weather?q=thoen&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #63: vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #64: qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?q=qasigiannguit&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #65: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #66: yar-sale
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #67: koslan
# http://api.openweathermap.org/data/2.5/weather?q=koslan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #68: billings
# http://api.openweathermap.org/data/2.5/weather?q=billings&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #69: hofn
# http://api.openweathermap.org/data/2.5/weather?q=hofn&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #70: vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #71: avera
# http://api.openweathermap.org/data/2.5/weather?q=avera&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #72: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #73: palmer
# http://api.openweathermap.org/data/2.5/weather?q=palmer&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #74: kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #75: la union
# http://api.openweathermap.org/data/2.5/weather?q=la union&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #76: nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?q=nuevo progreso&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #77: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #78: inhambane
# http://api.openweathermap.org/data/2.5/weather?q=inhambane&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #79: richards bay
# http://api.openweathermap.org/data/2.5/weather?q=richards bay&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #80: tomatlan
# http://api.openweathermap.org/data/2.5/weather?q=tomatlan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #81: christiansfeld
# http://api.openweathermap.org/data/2.5/weather?q=christiansfeld&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #82: zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #83: jabinyanah
# http://api.openweathermap.org/data/2.5/weather?q=jabinyanah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #84: pochutla
# http://api.openweathermap.org/data/2.5/weather?q=pochutla&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #85: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #86: hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #87: attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #88: guarapari
# http://api.openweathermap.org/data/2.5/weather?q=guarapari&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #89: zhitikara
# http://api.openweathermap.org/data/2.5/weather?q=zhitikara&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #90: ust-omchug
# http://api.openweathermap.org/data/2.5/weather?q=ust-omchug&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #91: vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #92: luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #93: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #94: payakumbuh
# http://api.openweathermap.org/data/2.5/weather?q=payakumbuh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #95: mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #96: port lincoln
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #97: worland
# http://api.openweathermap.org/data/2.5/weather?q=worland&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #98: zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?q=zhezkazgan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #99: valdivia
# http://api.openweathermap.org/data/2.5/weather?q=valdivia&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #100: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #101: puri
# http://api.openweathermap.org/data/2.5/weather?q=puri&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #102: masindi
# http://api.openweathermap.org/data/2.5/weather?q=masindi&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #103: yulara
# http://api.openweathermap.org/data/2.5/weather?q=yulara&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #104: iquique
# http://api.openweathermap.org/data/2.5/weather?q=iquique&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #105: la peca
# http://api.openweathermap.org/data/2.5/weather?q=la peca&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #106: tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #107: gombong
# http://api.openweathermap.org/data/2.5/weather?q=gombong&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #108: kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #109: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #110: ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?q=ust-tsilma&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #111: brekstad
# http://api.openweathermap.org/data/2.5/weather?q=brekstad&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #112: roblin
# http://api.openweathermap.org/data/2.5/weather?q=roblin&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #113: ziguinchor
# http://api.openweathermap.org/data/2.5/weather?q=ziguinchor&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #114: sisimiut
# http://api.openweathermap.org/data/2.5/weather?q=sisimiut&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #115: kamenka
# http://api.openweathermap.org/data/2.5/weather?q=kamenka&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #116: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #117: kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #118: victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #119: souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #120: ulaangom
# http://api.openweathermap.org/data/2.5/weather?q=ulaangom&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #121: ginir
# http://api.openweathermap.org/data/2.5/weather?q=ginir&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #122: wajir
# http://api.openweathermap.org/data/2.5/weather?q=wajir&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #123: jhikargachha
# http://api.openweathermap.org/data/2.5/weather?q=jhikargachha&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #124: broken hill
# http://api.openweathermap.org/data/2.5/weather?q=broken hill&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #125: umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?q=umm kaddadah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #126: hervey bay
# http://api.openweathermap.org/data/2.5/weather?q=hervey bay&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #127: limon
# http://api.openweathermap.org/data/2.5/weather?q=limon&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #128: palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #129: torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #130: clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #131: cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #132: yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #133: ambanja
# http://api.openweathermap.org/data/2.5/weather?q=ambanja&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #134: russell
# http://api.openweathermap.org/data/2.5/weather?q=russell&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #135: grand gaube
# http://api.openweathermap.org/data/2.5/weather?q=grand gaube&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #136: castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #137: moree
# http://api.openweathermap.org/data/2.5/weather?q=moree&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #138: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #139: lorengau
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #140: coffs harbour
# http://api.openweathermap.org/data/2.5/weather?q=coffs harbour&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #141: hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #142: concordia
# http://api.openweathermap.org/data/2.5/weather?q=concordia&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #143: touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #144: dunnville
# http://api.openweathermap.org/data/2.5/weather?q=dunnville&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #145: atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #146: saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #147: mizdah
# http://api.openweathermap.org/data/2.5/weather?q=mizdah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #148: ambilobe
# http://api.openweathermap.org/data/2.5/weather?q=ambilobe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #149: ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #150: carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #151: lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #152: lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #153: viedma
# http://api.openweathermap.org/data/2.5/weather?q=viedma&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #154: padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #155: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #156: charleston
# http://api.openweathermap.org/data/2.5/weather?q=charleston&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #157: mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?q=mokhsogollokh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #158: ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #159: itarema
# http://api.openweathermap.org/data/2.5/weather?q=itarema&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #160: krasnyy luch
# http://api.openweathermap.org/data/2.5/weather?q=krasnyy luch&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #161: kamina
# http://api.openweathermap.org/data/2.5/weather?q=kamina&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #162: ucluelet
# http://api.openweathermap.org/data/2.5/weather?q=ucluelet&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #163: mizan teferi
# http://api.openweathermap.org/data/2.5/weather?q=mizan teferi&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #164: jalpan
# http://api.openweathermap.org/data/2.5/weather?q=jalpan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #165: jahrom
# http://api.openweathermap.org/data/2.5/weather?q=jahrom&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #166: vanimo
# http://api.openweathermap.org/data/2.5/weather?q=vanimo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #167: yaan
# http://api.openweathermap.org/data/2.5/weather?q=yaan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #168: arman
# http://api.openweathermap.org/data/2.5/weather?q=arman&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #169: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #170: charters towers
# http://api.openweathermap.org/data/2.5/weather?q=charters towers&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #171: senneterre
# http://api.openweathermap.org/data/2.5/weather?q=senneterre&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #172: evensk
# http://api.openweathermap.org/data/2.5/weather?q=evensk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #173: dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #174: hongjiang
# http://api.openweathermap.org/data/2.5/weather?q=hongjiang&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #175: rawson
# http://api.openweathermap.org/data/2.5/weather?q=rawson&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #176: bouca
# http://api.openweathermap.org/data/2.5/weather?q=bouca&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #177: azimur
# http://api.openweathermap.org/data/2.5/weather?q=azimur&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #178: chom bung
# http://api.openweathermap.org/data/2.5/weather?q=chom bung&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #179: berbera
# http://api.openweathermap.org/data/2.5/weather?q=berbera&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #180: panaba
# http://api.openweathermap.org/data/2.5/weather?q=panaba&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #181: butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #182: xushan
# http://api.openweathermap.org/data/2.5/weather?q=xushan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #183: palanga
# http://api.openweathermap.org/data/2.5/weather?q=palanga&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #184: kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #185: mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #186: pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #187: santo antonio do monte
# http://api.openweathermap.org/data/2.5/weather?q=santo antonio do monte&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #188: dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #189: saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #190: porto walter
# http://api.openweathermap.org/data/2.5/weather?q=porto walter&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #191: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #192: rajnagar
# http://api.openweathermap.org/data/2.5/weather?q=rajnagar&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #193: colares
# http://api.openweathermap.org/data/2.5/weather?q=colares&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #194: coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #195: ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #196: ocos
# http://api.openweathermap.org/data/2.5/weather?q=ocos&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #197: hobyo
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #198: sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #199: port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port hardy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #200: daoukro
# http://api.openweathermap.org/data/2.5/weather?q=daoukro&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #201: faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #202: camacha
# http://api.openweathermap.org/data/2.5/weather?q=camacha&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #203: tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #204: ko samui
# http://api.openweathermap.org/data/2.5/weather?q=ko samui&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #205: lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #206: baculin
# http://api.openweathermap.org/data/2.5/weather?q=baculin&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #207: vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #208: puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?q=puerto leguizamo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #209: barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #210: boyolangu
# http://api.openweathermap.org/data/2.5/weather?q=boyolangu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #211: ponta delgada
# http://api.openweathermap.org/data/2.5/weather?q=ponta delgada&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #212: cornwall
# http://api.openweathermap.org/data/2.5/weather?q=cornwall&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #213: tilichiki
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #214: ola
# http://api.openweathermap.org/data/2.5/weather?q=ola&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #215: conselheiro pena
# http://api.openweathermap.org/data/2.5/weather?q=conselheiro pena&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #216: tygda
# http://api.openweathermap.org/data/2.5/weather?q=tygda&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #217: koson
# http://api.openweathermap.org/data/2.5/weather?q=koson&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #218: zhanaozen
# http://api.openweathermap.org/data/2.5/weather?q=zhanaozen&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #219: ouango
# http://api.openweathermap.org/data/2.5/weather?q=ouango&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #220: pemangkat
# http://api.openweathermap.org/data/2.5/weather?q=pemangkat&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #221: louisbourg
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #222: paamiut
# http://api.openweathermap.org/data/2.5/weather?q=paamiut&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #223: nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?q=nizhniy kuranakh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #224: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #225: fort walton beach
# http://api.openweathermap.org/data/2.5/weather?q=fort walton beach&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #226: amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #227: skalistyy
# http://api.openweathermap.org/data/2.5/weather?q=skalistyy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #228: norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #229: las choapas
# http://api.openweathermap.org/data/2.5/weather?q=las choapas&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #230: bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #231: eravur
# http://api.openweathermap.org/data/2.5/weather?q=eravur&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #232: nanakuli
# http://api.openweathermap.org/data/2.5/weather?q=nanakuli&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #233: bubaque
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #234: coro
# http://api.openweathermap.org/data/2.5/weather?q=coro&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #235: u thong
# http://api.openweathermap.org/data/2.5/weather?q=u thong&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #236: pitsunda
# http://api.openweathermap.org/data/2.5/weather?q=pitsunda&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #237: dumai
# http://api.openweathermap.org/data/2.5/weather?q=dumai&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #238: chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #239: ejido
# http://api.openweathermap.org/data/2.5/weather?q=ejido&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #240: isangel
# http://api.openweathermap.org/data/2.5/weather?q=isangel&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #241: nabire
# http://api.openweathermap.org/data/2.5/weather?q=nabire&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #242: chinsali
# http://api.openweathermap.org/data/2.5/weather?q=chinsali&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #243: dunedin
# http://api.openweathermap.org/data/2.5/weather?q=dunedin&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #244: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #245: aklavik
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #246: san jose
# http://api.openweathermap.org/data/2.5/weather?q=san jose&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #247: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #248: fort frances
# http://api.openweathermap.org/data/2.5/weather?q=fort frances&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #249: hamilton
# http://api.openweathermap.org/data/2.5/weather?q=hamilton&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #250: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #251: chara
# http://api.openweathermap.org/data/2.5/weather?q=chara&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #252: eluru
# http://api.openweathermap.org/data/2.5/weather?q=eluru&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #253: oum hadjer
# http://api.openweathermap.org/data/2.5/weather?q=oum hadjer&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #254: east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #255: san blas
# http://api.openweathermap.org/data/2.5/weather?q=san blas&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #256: huntsville
# http://api.openweathermap.org/data/2.5/weather?q=huntsville&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #257: yala
# http://api.openweathermap.org/data/2.5/weather?q=yala&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #258: berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?q=berdigestyakh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #259: plouzane
# http://api.openweathermap.org/data/2.5/weather?q=plouzane&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #260: rottingdean
# http://api.openweathermap.org/data/2.5/weather?q=rottingdean&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #261: airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #262: tabou
# http://api.openweathermap.org/data/2.5/weather?q=tabou&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #263: belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #264: tabiauea
# http://api.openweathermap.org/data/2.5/weather?q=tabiauea&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #265: adre
# http://api.openweathermap.org/data/2.5/weather?q=adre&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #266: karaidel
# http://api.openweathermap.org/data/2.5/weather?q=karaidel&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #267: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #268: cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #269: deputatskiy
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #270: saint-leu
# http://api.openweathermap.org/data/2.5/weather?q=saint-leu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# ...
# ------------------------
# Retrieving city #557: rawannawi
# http://api.openweathermap.org/data/2.5/weather?q=rawannawi&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #558: nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #559: zambezi
# http://api.openweathermap.org/data/2.5/weather?q=zambezi&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #560: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #561: olga
# http://api.openweathermap.org/data/2.5/weather?q=olga&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #562: hualmay
# http://api.openweathermap.org/data/2.5/weather?q=hualmay&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #563: talavera
# http://api.openweathermap.org/data/2.5/weather?q=talavera&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #564: port angeles
# http://api.openweathermap.org/data/2.5/weather?q=port angeles&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #565: miri
# http://api.openweathermap.org/data/2.5/weather?q=miri&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #566: kiruna
# http://api.openweathermap.org/data/2.5/weather?q=kiruna&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #567: moranbah
# http://api.openweathermap.org/data/2.5/weather?q=moranbah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #568: galle
# http://api.openweathermap.org/data/2.5/weather?q=galle&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #569: umba
# http://api.openweathermap.org/data/2.5/weather?q=umba&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #570: ajdabiya
# http://api.openweathermap.org/data/2.5/weather?q=ajdabiya&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #571: guigue
# http://api.openweathermap.org/data/2.5/weather?q=guigue&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #572: kabarnet
# http://api.openweathermap.org/data/2.5/weather?q=kabarnet&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #573: santa maria do suacui
# http://api.openweathermap.org/data/2.5/weather?q=santa maria do suacui&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #574: antalaha
# http://api.openweathermap.org/data/2.5/weather?q=antalaha&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #575: merauke
# http://api.openweathermap.org/data/2.5/weather?q=merauke&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #576: vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #577: soubre
# http://api.openweathermap.org/data/2.5/weather?q=soubre&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #578: dongsheng
# http://api.openweathermap.org/data/2.5/weather?q=dongsheng&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #579: okha
# http://api.openweathermap.org/data/2.5/weather?q=okha&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #580: karatau
# http://api.openweathermap.org/data/2.5/weather?q=karatau&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #581: paoua
# http://api.openweathermap.org/data/2.5/weather?q=paoua&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #582: clarence town
# http://api.openweathermap.org/data/2.5/weather?q=clarence town&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #583: ghorawal
# http://api.openweathermap.org/data/2.5/weather?q=ghorawal&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #584: zhireken
# http://api.openweathermap.org/data/2.5/weather?q=zhireken&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #585: dryden
# http://api.openweathermap.org/data/2.5/weather?q=dryden&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #586: san francisco
# http://api.openweathermap.org/data/2.5/weather?q=san francisco&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #587: aykhal
# http://api.openweathermap.org/data/2.5/weather?q=aykhal&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #588: kindu
# http://api.openweathermap.org/data/2.5/weather?q=kindu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #589: half moon bay
# http://api.openweathermap.org/data/2.5/weather?q=half moon bay&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #590: vijayapuri
# http://api.openweathermap.org/data/2.5/weather?q=vijayapuri&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #591: sorrento
# http://api.openweathermap.org/data/2.5/weather?q=sorrento&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #592: ribas do rio pardo
# http://api.openweathermap.org/data/2.5/weather?q=ribas do rio pardo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #593: yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?q=yuzhno-yeniseyskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #594: navalmoral de la mata
# http://api.openweathermap.org/data/2.5/weather?q=navalmoral de la mata&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #595: san felipe
# http://api.openweathermap.org/data/2.5/weather?q=san felipe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #596: bathsheba
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #597: san ramon de la nueva oran
# http://api.openweathermap.org/data/2.5/weather?q=san ramon de la nueva oran&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #598: salym
# http://api.openweathermap.org/data/2.5/weather?q=salym&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #599: bac can
# http://api.openweathermap.org/data/2.5/weather?q=bac can&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #600: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #601: yoichi
# http://api.openweathermap.org/data/2.5/weather?q=yoichi&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #602: pinega
# http://api.openweathermap.org/data/2.5/weather?q=pinega&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #603: walvis bay
# http://api.openweathermap.org/data/2.5/weather?q=walvis bay&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #604: lahij
# http://api.openweathermap.org/data/2.5/weather?q=lahij&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #605: talcahuano
# http://api.openweathermap.org/data/2.5/weather?q=talcahuano&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #606: esso
# http://api.openweathermap.org/data/2.5/weather?q=esso&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #607: san quintin
# http://api.openweathermap.org/data/2.5/weather?q=san quintin&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #608: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #609: wuwei
# http://api.openweathermap.org/data/2.5/weather?q=wuwei&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #610: waipawa
# http://api.openweathermap.org/data/2.5/weather?q=waipawa&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #611: luau
# http://api.openweathermap.org/data/2.5/weather?q=luau&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #612: korsor
# http://api.openweathermap.org/data/2.5/weather?q=korsor&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #613: maningrida
# http://api.openweathermap.org/data/2.5/weather?q=maningrida&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #614: solginskiy
# http://api.openweathermap.org/data/2.5/weather?q=solginskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #615: babanusah
# http://api.openweathermap.org/data/2.5/weather?q=babanusah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #616: kovdor
# http://api.openweathermap.org/data/2.5/weather?q=kovdor&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #617: pio xii
# http://api.openweathermap.org/data/2.5/weather?q=pio xii&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #618: kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #619: zvenyhorodka
# http://api.openweathermap.org/data/2.5/weather?q=zvenyhorodka&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #620: anchorage
# http://api.openweathermap.org/data/2.5/weather?q=anchorage&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #621: cabedelo
# http://api.openweathermap.org/data/2.5/weather?q=cabedelo&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #622: havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #623: tefe
# http://api.openweathermap.org/data/2.5/weather?q=tefe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #624: jugsalai
# http://api.openweathermap.org/data/2.5/weather?q=jugsalai&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #625: ouadda
# http://api.openweathermap.org/data/2.5/weather?q=ouadda&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #626: lata
# http://api.openweathermap.org/data/2.5/weather?q=lata&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #627: korla
# http://api.openweathermap.org/data/2.5/weather?q=korla&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #628: cayenne
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #629: nyagan
# http://api.openweathermap.org/data/2.5/weather?q=nyagan&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #630: krasnogvardeyskiy
# http://api.openweathermap.org/data/2.5/weather?q=krasnogvardeyskiy&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #631: shar
# http://api.openweathermap.org/data/2.5/weather?q=shar&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #632: beausejour
# http://api.openweathermap.org/data/2.5/weather?q=beausejour&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #633: vila do maio
# http://api.openweathermap.org/data/2.5/weather?q=vila do maio&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #634: saint-francois
# http://api.openweathermap.org/data/2.5/weather?q=saint-francois&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #635: susanville
# http://api.openweathermap.org/data/2.5/weather?q=susanville&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #636: samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #637: kuche
# http://api.openweathermap.org/data/2.5/weather?q=kuche&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #638: gillette
# http://api.openweathermap.org/data/2.5/weather?q=gillette&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #639: talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #640: naryan-mar
# http://api.openweathermap.org/data/2.5/weather?q=naryan-mar&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #641: hay river
# http://api.openweathermap.org/data/2.5/weather?q=hay river&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #642: pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #643: abu jubayhah
# http://api.openweathermap.org/data/2.5/weather?q=abu jubayhah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #644: maniitsoq
# http://api.openweathermap.org/data/2.5/weather?q=maniitsoq&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #645: asau
# http://api.openweathermap.org/data/2.5/weather?q=asau&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# Missing details... skip.
# ------------------------
# Retrieving city #646: alice springs
# http://api.openweathermap.org/data/2.5/weather?q=alice springs&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #647: buraydah
# http://api.openweathermap.org/data/2.5/weather?q=buraydah&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# ------------------------
# Retrieving city #648: maltahohe
# http://api.openweathermap.org/data/2.5/weather?q=maltahohe&units=IMPERIAL&appid=b12c496902bc510d29a8f3b9027c456a
# **********************
# DATA RETRIEVAL COMPLETE
# **********************

# %%
display(cities_df)
# Out:
#                    city country cloudiness        date humidity    lat  \
# 0    comodoro rivadavia      AR         20  1536681600       33 -45.87
# 1               ternate      PH         75  1536685200      100  14.29
# 2              meulaboh      ID         48  1536686124      100   4.14
# 3               ushuaia      AR         20  1536681600       65 -54.81
# 4               angoche      MZ          0  1536686124      100 -16.23
# 5              bengkulu
# 6             taolanaro
# 7                hobart      AU         75  1536684360       54 -42.88
# 8               rikitea      PF         56  1536686125       99 -23.12
# 9          punta arenas      CL          0  1536681600       49 -53.16
# 10            upernavik      GL         20  1536686126      100  72.79
# 11               barrow      AR         76  1536685880       73 -38.31
# 12           chokurdakh      RU         92  1536686126       92  70.62
# 13               avarua      CK         75  1536681600       73 -21.21
# 14     illoqqortoormiut
# 15          nizhneyansk
# 16                bluff      AU          0  1536686127       90 -23.58
# 17       severo-kurilsk      RU          0  1536686127      100  50.68
# 18            mogadishu      SO         88  1536686127       98   2.04
# 19               bergen
# 20           sao filipe      CV          0  1536686127       94   14.9
# 21        cockburn town      TC         20  1536686128      100  21.46
# 22             thompson      CA         90  1536685200       93  55.74
# 23          port alfred      ZA          0  1536686128       83 -33.59
# 24             barranca      PE         24  1536686129      100 -10.75
# 25             hermanus      ZA          0  1536686129       54 -34.42
# 26       gusinoye ozero      RU         32  1536686129       95  51.11
# 27          mys shmidta
# 28        tierra blanca      MX          8  1536686130       88  18.45
# 29              quesnel      CA         90  1536685200       87  52.98
# ..                  ...     ...        ...         ...      ...    ...
# 618        zvenyhorodka      UA         20  1536686353       91  49.08
# 619           anchorage      US          1  1536684960       99  61.22
# 620            cabedelo      BR         75  1536681600       61  -6.97
# 621  havre-saint-pierre      CA         90  1536681600       71  50.23
# 622                tefe      BR         75  1536685200       66  -3.35
# 623            jugsalai      IN         56  1536686354       96  22.77
# 624              ouadda      CF         44  1536686354      100   8.07
# 625                lata      IN         48  1536686354      100  30.78
# 626               korla
# 627             cayenne      GF          8  1536683400       59   4.94
# 628              nyagan      RU         64  1536686355       81  62.14
# 629   krasnogvardeyskiy      RU          0  1536686355       76  57.38
# 630                shar      NG          0  1536686355       84    7.3
# 631          beausejour      CA         75  1536685200       69  50.06
# 632        vila do maio      CV         75  1536681600       74  15.13
# 633      saint-francois      FR          0  1536685200       29  46.42
# 634          susanville      US          1  1536686100       22  40.42
# 635              samusu
# 636               kuche
# 637            gillette      US         36  1536686108       25  44.29
# 638             talnakh      RU         12  1536686356      100  69.49
# 639          naryan-mar      RU        100  1536686357       88  67.67
# 640           hay river      CA         75  1536685200       55  60.82
# 641               pisco      PE         90  1536681600       30 -13.71
# 642        abu jubayhah
# 643           maniitsoq      GL         68  1536686357      100  65.42
# 644                asau
# 645       alice springs      AU          0  1536685200       27  -23.7
# 646            buraydah      SA          0  1536681600       21  26.33
# 647           maltahohe      NA          0  1536686358       25 -24.83
#
#         lon temp_max wind_speed
# 0    -67.48     62.6      19.46
# 1    120.72     80.6       3.36
# 2     96.13    77.87       2.26
# 3    -68.31     48.2      13.87
# 4     39.91    76.25      12.44
# 5
# 6
# 7    147.33     57.2      27.51
# 8   -134.97    73.46      10.76
# 9    -70.91     46.4      24.16
# 10   -56.15    36.83      14.12
# 11   -60.23    62.93      17.69
# 12    147.9    43.13      14.34
# 13  -159.78     75.2      11.41
# 14
# 15
# 16   149.07    53.39       4.61
# 17   156.12    46.55         13
# 18    45.34    78.59      14.79
# 19
# 20    -24.5    79.94       9.98
# 21   -71.14    83.63       1.92
# 22   -97.86     39.2       3.27
# 23    26.89    67.34      12.88
# 24   -77.76    61.31      10.65
# 25    19.24    59.33       6.85
# 26   106.26    43.31       5.84
# 27
# 28   -96.36    85.07       3.71
# 29  -122.49     48.2       2.24
# ..      ...      ...        ...
# 618   30.97    63.83       7.52
# 619 -149.89    48.02       5.82
# 620  -34.84     82.4      18.34
# 621   -63.6     57.2       5.82
# 622  -64.71     87.8       6.93
# 623   86.18    76.07       3.27
# 624    22.4    69.59       4.72
# 625   78.62    56.54        1.7
# 626
# 627  -52.33     91.4       8.05
# 628   65.43    45.83       6.62
# 629   62.32    47.54       6.73
# 630    8.73    80.93       4.05
# 631  -96.51     75.2      17.22
# 632  -23.22     82.4       6.93
# 633    3.91     87.8       1.12
# 634 -120.65     69.8       3.36
# 635
# 636
# 637  -105.5    70.49      10.98
# 638   88.39    31.43       8.19
# 639   53.09     51.5      11.65
# 640 -115.79     35.6       8.05
# 641   -76.2     71.6      13.87
# 642
# 643   -52.9    40.07       6.51
# 644
# 645  133.88     64.4       8.05
# 646   43.97    102.2        4.7
# 647   16.98    63.02       9.53
#
# [648 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("cities_df.csv")

# %%
cities = pd.read_csv("cities_df.csv")
cities
# Out:
#      Unnamed: 0                city country  cloudiness          date  \
# 0             0  comodoro rivadavia      AR        20.0  1.536682e+09
# 1             1             ternate      PH        75.0  1.536685e+09
# 2             2            meulaboh      ID        48.0  1.536686e+09
# 3             3             ushuaia      AR        20.0  1.536682e+09
# 4             4             angoche      MZ         0.0  1.536686e+09
# 5             5            bengkulu     NaN         NaN           NaN
# 6             6           taolanaro     NaN         NaN           NaN
# 7             7              hobart      AU        75.0  1.536684e+09
# 8             8             rikitea      PF        56.0  1.536686e+09
# 9             9        punta arenas      CL         0.0  1.536682e+09
# 10           10           upernavik      GL        20.0  1.536686e+09
# 11           11              barrow      AR        76.0  1.536686e+09
# 12           12          chokurdakh      RU        92.0  1.536686e+09
# 13           13              avarua      CK        75.0  1.536682e+09
# 14           14    illoqqortoormiut     NaN         NaN           NaN
# 15           15         nizhneyansk     NaN         NaN           NaN
# 16           16               bluff      AU         0.0  1.536686e+09
# 17           17      severo-kurilsk      RU         0.0  1.536686e+09
# 18           18           mogadishu      SO        88.0  1.536686e+09
# 19           19              bergen     NaN         NaN           NaN
# 20           20          sao filipe      CV         0.0  1.536686e+09
# 21           21       cockburn town      TC        20.0  1.536686e+09
# 22           22            thompson      CA        90.0  1.536685e+09
# 23           23         port alfred      ZA         0.0  1.536686e+09
# 24           24            barranca      PE        24.0  1.536686e+09
# 25           25            hermanus      ZA         0.0  1.536686e+09
# 26           26      gusinoye ozero      RU        32.0  1.536686e+09
# 27           27         mys shmidta     NaN         NaN           NaN
# 28           28       tierra blanca      MX         8.0  1.536686e+09
# 29           29             quesnel      CA        90.0  1.536685e+09
# ..          ...                 ...     ...         ...           ...
# 618         618        zvenyhorodka      UA        20.0  1.536686e+09
# 619         619           anchorage      US         1.0  1.536685e+09
# 620         620            cabedelo      BR        75.0  1.536682e+09
# 621         621  havre-saint-pierre      CA        90.0  1.536682e+09
# 622         622                tefe      BR        75.0  1.536685e+09
# 623         623            jugsalai      IN        56.0  1.536686e+09
# 624         624              ouadda      CF        44.0  1.536686e+09
# 625         625                lata      IN        48.0  1.536686e+09
# 626         626               korla     NaN         NaN           NaN
# 627         627             cayenne      GF         8.0  1.536683e+09
# 628         628              nyagan      RU        64.0  1.536686e+09
# 629         629   krasnogvardeyskiy      RU         0.0  1.536686e+09
# 630         630                shar      NG         0.0  1.536686e+09
# 631         631          beausejour      CA        75.0  1.536685e+09
# 632         632        vila do maio      CV        75.0  1.536682e+09
# 633         633      saint-francois      FR         0.0  1.536685e+09
# 634         634          susanville      US         1.0  1.536686e+09
# 635         635              samusu     NaN         NaN           NaN
# 636         636               kuche     NaN         NaN           NaN
# 637         637            gillette      US        36.0  1.536686e+09
# 638         638             talnakh      RU        12.0  1.536686e+09
# 639         639          naryan-mar      RU       100.0  1.536686e+09
# 640         640           hay river      CA        75.0  1.536685e+09
# 641         641               pisco      PE        90.0  1.536682e+09
# 642         642        abu jubayhah     NaN         NaN           NaN
# 643         643           maniitsoq      GL        68.0  1.536686e+09
# 644         644                asau     NaN         NaN           NaN
# 645         645       alice springs      AU         0.0  1.536685e+09
# 646         646            buraydah      SA         0.0  1.536682e+09
# 647         647           maltahohe     NaN         0.0  1.536686e+09
#
#      humidity    lat     lon  temp_max  wind_speed
# 0        33.0 -45.87  -67.48     62.60       19.46
# 1       100.0  14.29  120.72     80.60        3.36
# 2       100.0   4.14   96.13     77.87        2.26
# 3        65.0 -54.81  -68.31     48.20       13.87
# 4       100.0 -16.23   39.91     76.25       12.44
# 5         NaN    NaN     NaN       NaN         NaN
# 6         NaN    NaN     NaN       NaN         NaN
# 7        54.0 -42.88  147.33     57.20       27.51
# 8        99.0 -23.12 -134.97     73.46       10.76
# 9        49.0 -53.16  -70.91     46.40       24.16
# 10      100.0  72.79  -56.15     36.83       14.12
# 11       73.0 -38.31  -60.23     62.93       17.69
# 12       92.0  70.62  147.90     43.13       14.34
# 13       73.0 -21.21 -159.78     75.20       11.41
# 14        NaN    NaN     NaN       NaN         NaN
# 15        NaN    NaN     NaN       NaN         NaN
# 16       90.0 -23.58  149.07     53.39        4.61
# 17      100.0  50.68  156.12     46.55       13.00
# 18       98.0   2.04   45.34     78.59       14.79
# 19        NaN    NaN     NaN       NaN         NaN
# 20       94.0  14.90  -24.50     79.94        9.98
# 21      100.0  21.46  -71.14     83.63        1.92
# 22       93.0  55.74  -97.86     39.20        3.27
# 23       83.0 -33.59   26.89     67.34       12.88
# 24      100.0 -10.75  -77.76     61.31       10.65
# 25       54.0 -34.42   19.24     59.33        6.85
# 26       95.0  51.11  106.26     43.31        5.84
# 27        NaN    NaN     NaN       NaN         NaN
# 28       88.0  18.45  -96.36     85.07        3.71
# 29       87.0  52.98 -122.49     48.20        2.24
# ..        ...    ...     ...       ...         ...
# 618      91.0  49.08   30.97     63.83        7.52
# 619      99.0  61.22 -149.89     48.02        5.82
# 620      61.0  -6.97  -34.84     82.40       18.34
# 621      71.0  50.23  -63.60     57.20        5.82
# 622      66.0  -3.35  -64.71     87.80        6.93
# 623      96.0  22.77   86.18     76.07        3.27
# 624     100.0   8.07   22.40     69.59        4.72
# 625     100.0  30.78   78.62     56.54        1.70
# 626       NaN    NaN     NaN       NaN         NaN
# 627      59.0   4.94  -52.33     91.40        8.05
# 628      81.0  62.14   65.43     45.83        6.62
# 629      76.0  57.38   62.32     47.54        6.73
# 630      84.0   7.30    8.73     80.93        4.05
# 631      69.0  50.06  -96.51     75.20       17.22
# 632      74.0  15.13  -23.22     82.40        6.93
# 633      29.0  46.42    3.91     87.80        1.12
# 634      22.0  40.42 -120.65     69.80        3.36
# 635       NaN    NaN     NaN       NaN         NaN
# 636       NaN    NaN     NaN       NaN         NaN
# 637      25.0  44.29 -105.50     70.49       10.98
# 638     100.0  69.49   88.39     31.43        8.19
# 639      88.0  67.67   53.09     51.50       11.65
# 640      55.0  60.82 -115.79     35.60        8.05
# 641      30.0 -13.71  -76.20     71.60       13.87
# 642       NaN    NaN     NaN       NaN         NaN
# 643     100.0  65.42  -52.90     40.07        6.51
# 644       NaN    NaN     NaN       NaN         NaN
# 645      27.0 -23.70  133.88     64.40        8.05
# 646      21.0  26.33   43.97    102.20        4.70
# 647      25.0 -24.83   16.98     63.02        9.53
#
# [648 rows x 10 columns]

# %%
cities.dropna(how='any').head(6)
# Out:
#    Unnamed: 0                city country  cloudiness          date  humidity  \
# 0           0  comodoro rivadavia      AR        20.0  1.536682e+09      33.0
# 1           1             ternate      PH        75.0  1.536685e+09     100.0
# 2           2            meulaboh      ID        48.0  1.536686e+09     100.0
# 3           3             ushuaia      AR        20.0  1.536682e+09      65.0
# 4           4             angoche      MZ         0.0  1.536686e+09     100.0
# 7           7              hobart      AU        75.0  1.536684e+09      54.0
#
#      lat     lon  temp_max  wind_speed
# 0 -45.87  -67.48     62.60       19.46
# 1  14.29  120.72     80.60        3.36
# 2   4.14   96.13     77.87        2.26
# 3 -54.81  -68.31     48.20       13.87
# 4 -16.23   39.91     76.25       12.44
# 7 -42.88  147.33     57.20       27.51

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
plt.scatter(cities.lat, cities.temp_max, marker='o', facecolors="royalblue", edgecolor="black")
plt.title("City Latitude vs Max Temp (9/9/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
# Out:
# Text(0,0.5,'Max Temp (F)')

# %%
plt.savefig("City Latitude vs Max Temp (9/9/2018).png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-2dc7b5c45957> in <module>()
# ----> 1 plt.savefig("City Latitude vs Max Temp (9/9/2018).png")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'City Latitude vs Max Temp (9/9/2018).png'

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities.lat, cities.humidity, marker='o', facecolors="deeppink", edgecolor="black")
plt.title("City Latitude vs Humidity (9/9/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# Text(0,0.5,'Humidity')

# %%
plt.savefig("City Latitude vs Humidity (9/9/18).png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-e7f3c2d779ee> in <module>()
# ----> 1 plt.savefig("City Latitude vs Humidity (9/9/18).png")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'City Latitude vs Humidity (9/9/18).png'

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities.lat, cities.cloudiness, marker='o', facecolors="mediumpurple", edgecolor="black", alpha=1.0)
plt.title("City Latitude vs Cloudiness (9/9/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0,0.5,'Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities.lat, cities.wind_speed, marker='o', facecolors="deepskyblue", edgecolor="black")
plt.title("City Latitude vs Wind Speed (9/9/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-adab1a0bb2ef> in <module>()
#       4 plt.ylabel("Wind Speed")
#       5
# ----> 6 plt.close(fig)
#
# NameError: name 'fig' is not defined

# %%
plt.savefig("City Latitude vs Wind Speed (9/9/2018).png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-3b0a5aa9be67> in <module>()
# ----> 1 plt.savefig("City Latitude vs Wind Speed (9/9/2018).png")
#       2 plt.close(fig)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'City Latitude vs Wind Speed (9/9/2018).png'
